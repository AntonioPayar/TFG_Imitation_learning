# %%
import numpy as np
import pandas as pd
import cv2
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df_mini = pd.read_csv('../datos/datos_bo3_minimapa.csv')
df_pov = pd.read_csv('../datos/datos_bo3_pov.csv')

# %%
df_mini.head()
# Out:
#                                      mini_01  \
# 0  datos/mini_mapa/mini_mapa_24-13-35-32.jpg
# 1  datos/mini_mapa/mini_mapa_24-13-35-35.jpg
# 2  datos/mini_mapa/mini_mapa_24-13-35-38.jpg
# 3  datos/mini_mapa/mini_mapa_24-13-35-41.jpg
# 4  datos/mini_mapa/mini_mapa_24-13-35-44.jpg
#
#                                      mini_02  \
# 0  datos/mini_mapa/mini_mapa_24-13-35-32.jpg
# 1  datos/mini_mapa/mini_mapa_24-13-35-36.jpg
# 2  datos/mini_mapa/mini_mapa_24-13-35-39.jpg
# 3  datos/mini_mapa/mini_mapa_24-13-35-42.jpg
# 4  datos/mini_mapa/mini_mapa_24-13-35-45.jpg
#
#                                      mini_03  \
# 0  datos/mini_mapa/mini_mapa_24-13-35-33.jpg
# 1  datos/mini_mapa/mini_mapa_24-13-35-36.jpg
# 2  datos/mini_mapa/mini_mapa_24-13-35-39.jpg
# 3  datos/mini_mapa/mini_mapa_24-13-35-42.jpg
# 4  datos/mini_mapa/mini_mapa_24-13-35-45.jpg
#
#                                      mini_04  \
# 0  datos/mini_mapa/mini_mapa_24-13-35-33.jpg
# 1  datos/mini_mapa/mini_mapa_24-13-35-37.jpg
# 2  datos/mini_mapa/mini_mapa_24-13-35-40.jpg
# 3  datos/mini_mapa/mini_mapa_24-13-35-43.jpg
# 4  datos/mini_mapa/mini_mapa_24-13-35-46.jpg
#
#                                      mini_05     mouse_final
# 0  datos/mini_mapa/mini_mapa_24-13-35-34.jpg  [0, 2859, 540]
# 1  datos/mini_mapa/mini_mapa_24-13-35-37.jpg  [0, 3033, 540]
# 2  datos/mini_mapa/mini_mapa_24-13-35-40.jpg  [0, 2903, 531]
# 3  datos/mini_mapa/mini_mapa_24-13-35-43.jpg  [0, 2880, 540]
# 4  datos/mini_mapa/mini_mapa_24-13-35-46.jpg  [0, 2880, 540]

# %%
print(df_mini.shape)
print(df_pov.shape)
# Out:
# (607, 6)
# (607, 6)

# %%
fig, axes = plt.subplots(1, 5, figsize=(15, 3))

for i in range(0,5):
    primera_fila = df_mini.iloc[0]
    imagen = Image.open("../" +str(primera_fila.iloc[i]))
    matriz_np = np.array(imagen)  

    axes[i].imshow(matriz_np)
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 5, figsize=(15, 5))

for i in range(3): 
    for j in range(5):
        # Obtener la ruta de la imagen
        ruta_imagen = df_mini.iloc[i, j]  # Elimina los corchetes
        
        # Abrir la imagen y convertirla a matriz numpy
        imagen = Image.open("../" + ruta_imagen)
        matriz_np = np.array(imagen)
        
        # Mostrar la imagen en el subplot correspondiente
        axes[i, j].imshow(matriz_np)
        axes[i, j].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(15, 3))

for i in range(0,5):
    primera_fila = df_pov.iloc[0]
    imagen = Image.open("../" +str(primera_fila.iloc[i]))
    matriz_np = np.array(imagen)  

    axes[i].imshow(matriz_np)
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 5, figsize=(15, 5))

for i in range(3): 
    for j in range(5):
        # Obtener la ruta de la imagen
        ruta_imagen = df_pov.iloc[i, j]  # Elimina los corchetes
        
        # Abrir la imagen y convertirla a matriz numpy
        imagen = Image.open("../" + ruta_imagen)
        matriz_np = np.array(imagen)
        
        # Mostrar la imagen en el subplot correspondiente
        axes[i, j].imshow(matriz_np)
        axes[i, j].axis('off')

plt.tight_layout()
plt.show()

# %%
primera_fila = df_mini.iloc[0]
imagen = Image.open("../" +str(primera_fila.iloc[1]))
matriz_np = np.array(imagen)  
print("Tamaño imagen -> "+str(imagen.size))
print("Tamaño matriz -> "+ str(matriz_np.shape))
plt.imshow(matriz_np)
plt.axis('on')
plt.show()
# Out:
# Tamaño imagen -> (135, 93)
# Tamaño matriz -> (93, 135, 3)

# %%
primera_fila = df_pov.iloc[0]
imagen = Image.open("../" +str(primera_fila.iloc[1]))
matriz_np = np.array(imagen)  
print("Tamaño imagen -> "+str(imagen.size))
print("Tamaño matriz -> "+ str(matriz_np.shape))
plt.imshow(matriz_np)
plt.axis('on') 
plt.show()
# Out:
# Tamaño imagen -> (320, 180)
# Tamaño matriz -> (180, 320, 3)

# %%
def comprobar_contenido(X_train , Y_train , num_video):

    fig, axs = plt.subplots(1, 5, figsize=(5 * 2, 1 * 2))

    for i in range(5):
        axs[i].imshow(X_train[num_video][i])
        axs[i].axis('off')

    plt.tight_layout()
    plt.show()
    print("Etiqueta -> "+ str(Y_train[num_video]))
    return Y_train[num_video]

# %% [markdown]
# # CREACION BATCH_DISTRIBUTION

# %% [markdown]
# #### Dado que mi equipo no es lo suficientemente potente como para cargar todas las imgenes en la RAM
# #### Procedo a crear una clase que distribuya mi Dataset en pequeños trozos conocidos como BATCHES
#
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
from tensorflow.keras.models import Model ,Sequential
from tensorflow.keras.layers import Input, TimeDistributed, MaxPooling2D, Flatten, Dense ,ConvLSTM2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from keras.utils import Sequence
# Out:
# 2024-06-24 14:17:24.103927: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-24 14:17:24.504116: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI AVX512_BF16, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
class ImageDataGenerator(Sequence):
    def __init__(self, df , sequence_length ,image_height , image_width , batch_size=32, **kwargs):
        self.df = df
        self.image_sequence_length = sequence_length
        self.image_height = image_height
        self.image_width = image_width
        self.batch_size = batch_size
        super().__init__(**kwargs)  # Llamada al constructor de la clase base
        
    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))
    
    def __getitem__(self, index):
        inicio_lote = index * self.batch_size
        final_lote = (index + 1) * self.batch_size
        
        batch_df = self.df.iloc[inicio_lote:final_lote]     #Obtenemos un lote del df
        
        X_batch = np.zeros((len(batch_df), self.image_sequence_length ,self.image_height, self.image_width, 3))  # Inicializar matriz para las imágenes
        y_batch = np.array([eval(mouse_final) for mouse_final in batch_df['mouse_final']])          #Almacenamos todas las label del df que corresponden al batch
        
        for i, (_, row) in enumerate(batch_df.iterrows()):
            frames = []
            for j in range(self.image_sequence_length):
                imagen = Image.open("../" + row.iloc[j])    # Obtener la ruta de la imagen
                imagen = np.array(imagen) / 255.0           # Normalizar la imagen

                frames.append(imagen)                  #Juntamos frames en lista
            video = np.stack(frames, axis=0)           # Convertir lista de frames en un video np
            X_batch[i] = video
        
        return X_batch, y_batch

# %%
df_mini.shape
# Out:
# (220, 6)

# %%
# Crear generadores de Batches
train_generator = ImageDataGenerator(df_mini, sequence_length=5 ,image_height=altura_img_mini , image_width=anchura_img_mini, batch_size=32)

# %%
#Cantidad de batches en los que se divide el df
train_generator.__len__()
# Out:
# 7

# %%
# Obtenemos el batch numero (1)
X_batch, y_batch = train_generator.__getitem__(1)

# %%
X_batch.shape
# Out:
# (32, 5, 183, 268, 3)

# %%
# Comprobamos si el batch produce correctamente las imagenes y las labels
# Seleccionamos ver la posicion numero 40 del batch creado
comprobar_contenido(X_batch , y_batch,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27545/4277712525.py in <module>
#       1 # Comprobamos si el batch produce correctamente las imagenes y las labels
#       2 # Seleccionamos ver la posicion numero 40 del batch creado
# ----> 3 comprobar_contenido(X_batch , y_batch,0)
#
# NameError: name 'X_batch' is not defined

# %%
y_batch
# Out:
# array([[1015,  550],
#        [1015,  550],
#        [1015,  550],
#        [1015,  550],
#        [1015,  550],
#        [1015,  550],
#        [ 990,  540],
#        [ 950,  537],
#        [ 950,  537],
#        [ 956,  541],
#        [ 961,  540],
#        [ 789,  533],
#        [ 962,  540],
#        [1254,  540],
#        [1254,  540],
#        [ 950,  540],
#        [ 936,  540],
#        [ 934,  540],
#        [ 959,  540],
#        [1042,  540],
#        [1006,  540],
#        [ 959,  542],
#        [ 926,  546],
#        [ 960,  540],
#        [ 959,  540],
#        [ 958,  540],
#        [1112,  491],
#        [ 970,  534],
#        [1010,  545],
#        [ 746,  509],
#        [ 960,  540],
#        [ 957,  540]])

# %%
type(y_batch[0][0])
# Out:
# numpy.int32

# %% [markdown]
# # CREACION MODELO LSTM_CNN

# %% [markdown]
# <div style="text-align:center;">
#     <iframe width="360" height="240" src="https://www.youtube.com/embed/deVW91RR_lQ" title="Deep Learning - 05 17 CNN LSTM" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# </div>
#
# https://www.kaggle.com/code/alextrinity/multi-head-cnn-bigru-cross-attention

# %%
def creacion_modelo_convLSTM(input_shape):
    
    model = Sequential()
    model.add(Input(shape=input_shape))
    
    # Capa ConvLSTM_01
    model.add(ConvLSTM2D(filters= 128, kernel_size=(4, 4), 
                                    activation='relu', 
                                    padding='same',
                                    return_sequences=True))
    model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
    model.add(TimeDistributed(BatchNormalization()))

    # Capa ConvLSTM_02
    model.add(ConvLSTM2D(filters= 64, kernel_size=(8, 8), 
                                    activation='relu', 
                                    padding='same', 
                                    return_sequences=True))
    model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
    model.add(TimeDistributed(BatchNormalization()))

    # Otra capa ConvLSTM_03
    model.add(ConvLSTM2D(filters=32, kernel_size=(8, 8), 
                         activation='relu', 
                         padding='same', 
                         return_sequences=False))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(BatchNormalization())
    
    
    # Capa densa adicional
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))  # Capa densa adicional
    model.add(Dense(3))  # Salida para regresión con 3 unidades (ejemplo)

    return model

# %% [markdown]
# # PREPARACIÒN ENTRENAMIENTO

# %%
# Modelo Mini-Mapa
df_train_mini, df_test_mini = train_test_split(df_mini, test_size=0.2, random_state=42)
df_train_mini, df_valid_mini = train_test_split(df_train_mini, test_size=0.25, random_state=42)

print("Tamaño total: ",len(df_mini))
print("Tamaño del conjunto de entrenamiento:", len(df_train_mini))
print("Tamaño del conjunto de validación:", len(df_valid_mini))
print("Tamaño del conjunto de prueba:", len(df_test_mini))
# Out:
# Tamaño total:  607
# Tamaño del conjunto de entrenamiento: 363
# Tamaño del conjunto de validación: 122
# Tamaño del conjunto de prueba: 122

# %%
# Modelo Pov
df_train_pov, df_test_pov = train_test_split(df_pov, test_size=0.2, random_state=42)
df_train_pov, df_valid_pov = train_test_split(df_train_pov, test_size=0.25, random_state=42)

print("Tamaño total: ",len(df_pov))
print("Tamaño del conjunto de entrenamiento:", len(df_train_pov))
print("Tamaño del conjunto de validación:", len(df_valid_pov))
print("Tamaño del conjunto de prueba:", len(df_test_pov))
# Out:
# Tamaño total:  220
# Tamaño del conjunto de entrenamiento: 132
# Tamaño del conjunto de validación: 44
# Tamaño del conjunto de prueba: 44

# %%
altura_img_mini = 93
anchura_img_mini = 135
batch_size = 4

# %%
# Generadores de Batches Mini-Mapa
train_generator_mapa = ImageDataGenerator(df_train_mini, sequence_length=5, image_height=altura_img_mini, image_width=anchura_img_mini, batch_size=batch_size)
valid_generator_mapa = ImageDataGenerator(df_valid_mini, sequence_length=5, image_height=altura_img_mini, image_width=anchura_img_mini, batch_size=batch_size)

# %%
# Obtenemos el batch numero (1)
X_batch, y_batch = train_generator_mapa.__getitem__(1)

# Comprobamos si el batch produce correctamente las imagenes y las labels
# Seleccionamos ver la posicion numero 40 del batch creado
tar = comprobar_contenido(X_batch , y_batch,0)
# Out:
# Etiqueta -> [   0 2893  540]

# %%
tar
# Out:
# array([   0, 2893,  540])

# %%
# Generadores de Batches POV
train_generator_pov = ImageDataGenerator(df_train_pov, sequence_length=5, image_height=720, image_width=1280, batch_size=batch_size)
valid_generator_pov = ImageDataGenerator(df_valid_pov, sequence_length=5, image_height=720, image_width=1280, batch_size=batch_size)

# %%
# Modelo Mini-Mapa
timesteps = 5
height = 93
width = 135
channels = 3
input_shape = (timesteps, height, width, channels)

model_mini_mapa = creacion_modelo_convLSTM(input_shape)
model_mini_mapa.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

# %%
model_mini_mapa.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 5, 93, 135, 128)   1073664
#
#  time_distributed_4 (TimeDi  (None, 5, 46, 67, 128)    0
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 5, 46, 67, 128)    512
#  stributed)
#
#  conv_lstm2d_4 (ConvLSTM2D)  (None, 5, 46, 67, 64)     3145984
#
#  time_distributed_6 (TimeDi  (None, 5, 23, 33, 64)     0
#  stributed)
#
#  time_distributed_7 (TimeDi  (None, 5, 23, 33, 64)     256
#  stributed)
#
#  conv_lstm2d_5 (ConvLSTM2D)  (None, 23, 33, 32)        786560
#
#  max_pooling2d_5 (MaxPoolin  (None, 11, 16, 32)        0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 11, 16, 32)        128
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 5632)              0
#
#  dense_2 (Dense)             (None, 64)                360512
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 5367811 (20.48 MB)
# Trainable params: 5367363 (20.47 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
# Verificar dispositivos disponibles
if tf.test.gpu_device_name():
    print('GPU encontrada:', tf.test.gpu_device_name())
else:
    print("No se encontró GPU. Se utilizará la CPU.")
# Out:
# GPU encontrada: /device:GPU:0
# 2024-06-24 14:25:58.763090: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-24 14:25:58.763341: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-24 14:25:58.763491: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-24 14:25:58.763711: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-24 14:25:58.763909: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-24 14:25:58.764047: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:0 with 6893 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2024-06-24 14:25:58.764199: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-24 14:25:58.764538: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-24 14:25:58.764734: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-24 14:25:58.764903: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-24 14:25:58.765044: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-24 14:25:58.765150: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:0 with 6893 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
# Entrenamiento Mini-Mapa
history = model_mini_mapa.fit(train_generator_mapa, epochs=1000, validation_data=valid_generator_mapa, callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# 2024-06-24 14:28:10.748039: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7df4f82c2580 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-06-24 14:28:10.748057: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1070, Compute Capability 6.1
# 2024-06-24 14:28:10.798608: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-24 14:28:11.090132: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 91/91 [==============================] - 88s 915ms/step - loss: 50710.7812 - accuracy: 0.0000e+00 - val_loss: 54924.8242 - val_accuracy: 0.0000e+00
# Epoch 2/1000
# 91/91 [==============================] - 83s 908ms/step - loss: 54980.7656 - accuracy: 0.0000e+00 - val_loss: 55147.2734 - val_accuracy: 0.0000e+00
# Epoch 3/1000
# 91/91 [==============================] - 83s 915ms/step - loss: 54980.7695 - accuracy: 0.0000e+00 - val_loss: 55147.2734 - val_accuracy: 0.0000e+00
# Epoch 4/1000
# 91/91 [==============================] - 83s 915ms/step - loss: 54980.7617 - accuracy: 0.0000e+00 - val_loss: 55147.2734 - val_accuracy: 0.0000e+00
# Epoch 5/1000
# 91/91 [==============================] - 83s 910ms/step - loss: 54980.7773 - accuracy: 0.0000e+00 - val_loss: 55147.2734 - val_accuracy: 0.0000e+00
# Epoch 6/1000
# 91/91 [==============================] - 83s 913ms/step - loss: 54980.7773 - accuracy: 0.0000e+00 - val_loss: 55147.2734 - val_accuracy: 0.0000e+00
# Epoch 7/1000
# 91/91 [==============================] - 83s 912ms/step - loss: 54980.7695 - accuracy: 0.0000e+00 - val_loss: 55147.2734 - val_accuracy: 0.0000e+00
# Epoch 8/1000
# 91/91 [==============================] - 83s 912ms/step - loss: 54980.7695 - accuracy: 0.0000e+00 - val_loss: 55147.2734 - val_accuracy: 0.0000e+00
# Epoch 9/1000
# 91/91 [==============================] - 83s 912ms/step - loss: 54980.7656 - accuracy: 0.0000e+00 - val_loss: 55147.2734 - val_accuracy: 0.0000e+00
# Epoch 10/1000
# 91/91 [==============================] - 83s 912ms/step - loss: 54980.7695 - accuracy: 0.0000e+00 - val_loss: 55147.2734 - val_accuracy: 0.0000e+00
# Epoch 11/1000
# 91/91 [==============================] - ETA: 0s - loss: 54980.7695 - accuracy: 0.0000e+00Restoring model weights from the end of the best epoch: 1.
# 91/91 [==============================] - 83s 910ms/step - loss: 54980.7695 - accuracy: 0.0000e+00 - val_loss: 55147.2734 - val_accuracy: 0.0000e+00
# Epoch 11: early stopping

# %%
# Evaluar el modelo en el conjunto de datos de prueba
test_loss, test_accuracy = model_mini_mapa.evaluate(valid_generator_mapa)

print(f'Loss en el conjunto de datos de prueba: {test_loss}')
print(f'Accuracy en el conjunto de datos de prueba: {test_accuracy}')
# Out:
# 31/31 [==============================] - 8s 253ms/step - loss: 54924.8242 - accuracy: 0.0000e+00
# Loss en el conjunto de datos de prueba: 54924.82421875
# Accuracy en el conjunto de datos de prueba: 0.0

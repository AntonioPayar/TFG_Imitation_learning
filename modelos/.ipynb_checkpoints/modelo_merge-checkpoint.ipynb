# %%
import numpy as np
import pandas as pd
import cv2
from PIL import Image, ImageEnhance ,ImageFilter
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df_mini = pd.read_csv('../datos/grabacion/datos_bo3_minimapa_prueba.csv')
df_pov = pd.read_csv('../datos/grabacion/datos_bo3_pov_prueba.csv')

# %%
df_mini.head(20)
# Out:
#                                               mini_01  \
# 0   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 1   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 2   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 3   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 4   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 5   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 6   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 7   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 8   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 9   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 10  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 11  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 12  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 13  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 14  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
# 15  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 16  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 17  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 18  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 19  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
#
#                                               mini_02  \
# 0   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 1   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 2   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 3   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 4   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 5   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 6   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 7   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 8   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 9   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 10  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 11  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 12  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 13  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 14  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
# 15  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 16  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 17  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 18  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 19  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
#
#                                               mini_03  \
# 0   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 1   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 2   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 3   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 4   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 5   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 6   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 7   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 8   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 9   datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
# 10  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 11  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 12  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 13  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
# 14  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
# 15  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 16  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 17  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 18  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
# 19  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
#
#                                               mini_04  \
# 0   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 1   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 2   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 3   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 4   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 5   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 6   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 7   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 8   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 9   datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
# 10  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 11  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 12  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 13  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
# 14  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
# 15  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 16  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 17  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...
# 18  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
# 19  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...
#
#                                               mini_05 mouse_final
# 0   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...    [27, -5]
# 1   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...    [27, -5]
# 2   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...      [0, 0]
# 3   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...    [27, -5]
# 4   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...      [0, 0]
# 5   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...   [-106, 4]
# 6   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...    [27, -5]
# 7   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...      [0, 0]
# 8   datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...   [-106, 4]
# 9   datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...    [171, 0]
# 10  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...    [27, -5]
# 11  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...      [0, 0]
# 12  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...   [-106, 4]
# 13  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...    [171, 0]
# 14  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...    [-66, 7]
# 15  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...    [27, -5]
# 16  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...      [0, 0]
# 17  datos/grabacion/mini_mapa/mini_mapa_29-18-02-2...   [-106, 4]
# 18  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...    [171, 0]
# 19  datos/grabacion/mini_mapa/mini_mapa_29-18-02-3...    [-66, 7]

# %%
df_pov.head(20)
# Out:
#                                             pov_01  \
# 0   datos/grabacion/pov/pov_29-18-02-26-096257.jpg
# 1   datos/grabacion/pov/pov_29-18-02-26-096257.jpg
# 2   datos/grabacion/pov/pov_29-18-02-27-371299.jpg
# 3   datos/grabacion/pov/pov_29-18-02-26-096257.jpg
# 4   datos/grabacion/pov/pov_29-18-02-27-371299.jpg
# 5   datos/grabacion/pov/pov_29-18-02-28-541824.jpg
# 6   datos/grabacion/pov/pov_29-18-02-26-096257.jpg
# 7   datos/grabacion/pov/pov_29-18-02-27-371299.jpg
# 8   datos/grabacion/pov/pov_29-18-02-28-541824.jpg
# 9   datos/grabacion/pov/pov_29-18-02-29-684082.jpg
# 10  datos/grabacion/pov/pov_29-18-02-26-096257.jpg
# 11  datos/grabacion/pov/pov_29-18-02-27-371299.jpg
# 12  datos/grabacion/pov/pov_29-18-02-28-541824.jpg
# 13  datos/grabacion/pov/pov_29-18-02-29-684082.jpg
# 14  datos/grabacion/pov/pov_29-18-02-30-834938.jpg
# 15  datos/grabacion/pov/pov_29-18-02-26-096257.jpg
# 16  datos/grabacion/pov/pov_29-18-02-27-371299.jpg
# 17  datos/grabacion/pov/pov_29-18-02-28-541824.jpg
# 18  datos/grabacion/pov/pov_29-18-02-29-684082.jpg
# 19  datos/grabacion/pov/pov_29-18-02-30-834938.jpg
#
#                                             pov_02  \
# 0   datos/grabacion/pov/pov_29-18-02-26-321979.jpg
# 1   datos/grabacion/pov/pov_29-18-02-26-321979.jpg
# 2   datos/grabacion/pov/pov_29-18-02-27-631116.jpg
# 3   datos/grabacion/pov/pov_29-18-02-26-321979.jpg
# 4   datos/grabacion/pov/pov_29-18-02-27-631116.jpg
# 5   datos/grabacion/pov/pov_29-18-02-28-772586.jpg
# 6   datos/grabacion/pov/pov_29-18-02-26-321979.jpg
# 7   datos/grabacion/pov/pov_29-18-02-27-631116.jpg
# 8   datos/grabacion/pov/pov_29-18-02-28-772586.jpg
# 9   datos/grabacion/pov/pov_29-18-02-29-912598.jpg
# 10  datos/grabacion/pov/pov_29-18-02-26-321979.jpg
# 11  datos/grabacion/pov/pov_29-18-02-27-631116.jpg
# 12  datos/grabacion/pov/pov_29-18-02-28-772586.jpg
# 13  datos/grabacion/pov/pov_29-18-02-29-912598.jpg
# 14  datos/grabacion/pov/pov_29-18-02-31-059719.jpg
# 15  datos/grabacion/pov/pov_29-18-02-26-321979.jpg
# 16  datos/grabacion/pov/pov_29-18-02-27-631116.jpg
# 17  datos/grabacion/pov/pov_29-18-02-28-772586.jpg
# 18  datos/grabacion/pov/pov_29-18-02-29-912598.jpg
# 19  datos/grabacion/pov/pov_29-18-02-31-059719.jpg
#
#                                             pov_03  \
# 0   datos/grabacion/pov/pov_29-18-02-26-539160.jpg
# 1   datos/grabacion/pov/pov_29-18-02-26-539160.jpg
# 2   datos/grabacion/pov/pov_29-18-02-27-861158.jpg
# 3   datos/grabacion/pov/pov_29-18-02-26-539160.jpg
# 4   datos/grabacion/pov/pov_29-18-02-27-861158.jpg
# 5   datos/grabacion/pov/pov_29-18-02-28-998902.jpg
# 6   datos/grabacion/pov/pov_29-18-02-26-539160.jpg
# 7   datos/grabacion/pov/pov_29-18-02-27-861158.jpg
# 8   datos/grabacion/pov/pov_29-18-02-28-998902.jpg
# 9   datos/grabacion/pov/pov_29-18-02-30-147756.jpg
# 10  datos/grabacion/pov/pov_29-18-02-26-539160.jpg
# 11  datos/grabacion/pov/pov_29-18-02-27-861158.jpg
# 12  datos/grabacion/pov/pov_29-18-02-28-998902.jpg
# 13  datos/grabacion/pov/pov_29-18-02-30-147756.jpg
# 14  datos/grabacion/pov/pov_29-18-02-31-281642.jpg
# 15  datos/grabacion/pov/pov_29-18-02-26-539160.jpg
# 16  datos/grabacion/pov/pov_29-18-02-27-861158.jpg
# 17  datos/grabacion/pov/pov_29-18-02-28-998902.jpg
# 18  datos/grabacion/pov/pov_29-18-02-30-147756.jpg
# 19  datos/grabacion/pov/pov_29-18-02-31-281642.jpg
#
#                                             pov_04  \
# 0   datos/grabacion/pov/pov_29-18-02-26-757697.jpg
# 1   datos/grabacion/pov/pov_29-18-02-26-757697.jpg
# 2   datos/grabacion/pov/pov_29-18-02-28-092721.jpg
# 3   datos/grabacion/pov/pov_29-18-02-26-757697.jpg
# 4   datos/grabacion/pov/pov_29-18-02-28-092721.jpg
# 5   datos/grabacion/pov/pov_29-18-02-29-226355.jpg
# 6   datos/grabacion/pov/pov_29-18-02-26-757697.jpg
# 7   datos/grabacion/pov/pov_29-18-02-28-092721.jpg
# 8   datos/grabacion/pov/pov_29-18-02-29-226355.jpg
# 9   datos/grabacion/pov/pov_29-18-02-30-384932.jpg
# 10  datos/grabacion/pov/pov_29-18-02-26-757697.jpg
# 11  datos/grabacion/pov/pov_29-18-02-28-092721.jpg
# 12  datos/grabacion/pov/pov_29-18-02-29-226355.jpg
# 13  datos/grabacion/pov/pov_29-18-02-30-384932.jpg
# 14  datos/grabacion/pov/pov_29-18-02-31-514656.jpg
# 15  datos/grabacion/pov/pov_29-18-02-26-757697.jpg
# 16  datos/grabacion/pov/pov_29-18-02-28-092721.jpg
# 17  datos/grabacion/pov/pov_29-18-02-29-226355.jpg
# 18  datos/grabacion/pov/pov_29-18-02-30-384932.jpg
# 19  datos/grabacion/pov/pov_29-18-02-31-514656.jpg
#
#                                             pov_05 mouse_final
# 0   datos/grabacion/pov/pov_29-18-02-26-982074.jpg    [27, -5]
# 1   datos/grabacion/pov/pov_29-18-02-26-982074.jpg    [27, -5]
# 2   datos/grabacion/pov/pov_29-18-02-28-313528.jpg      [0, 0]
# 3   datos/grabacion/pov/pov_29-18-02-26-982074.jpg    [27, -5]
# 4   datos/grabacion/pov/pov_29-18-02-28-313528.jpg      [0, 0]
# 5   datos/grabacion/pov/pov_29-18-02-29-455969.jpg   [-106, 4]
# 6   datos/grabacion/pov/pov_29-18-02-26-982074.jpg    [27, -5]
# 7   datos/grabacion/pov/pov_29-18-02-28-313528.jpg      [0, 0]
# 8   datos/grabacion/pov/pov_29-18-02-29-455969.jpg   [-106, 4]
# 9   datos/grabacion/pov/pov_29-18-02-30-606285.jpg    [171, 0]
# 10  datos/grabacion/pov/pov_29-18-02-26-982074.jpg    [27, -5]
# 11  datos/grabacion/pov/pov_29-18-02-28-313528.jpg      [0, 0]
# 12  datos/grabacion/pov/pov_29-18-02-29-455969.jpg   [-106, 4]
# 13  datos/grabacion/pov/pov_29-18-02-30-606285.jpg    [171, 0]
# 14  datos/grabacion/pov/pov_29-18-02-31-745705.jpg    [-66, 7]
# 15  datos/grabacion/pov/pov_29-18-02-26-982074.jpg    [27, -5]
# 16  datos/grabacion/pov/pov_29-18-02-28-313528.jpg      [0, 0]
# 17  datos/grabacion/pov/pov_29-18-02-29-455969.jpg   [-106, 4]
# 18  datos/grabacion/pov/pov_29-18-02-30-606285.jpg    [171, 0]
# 19  datos/grabacion/pov/pov_29-18-02-31-745705.jpg    [-66, 7]

# %%
print(df_mini.shape)
print(df_pov.shape)
# Out:
# (27255, 6)
# (27255, 6)

# %%
#Eliminamos duplicados
df_mini.drop_duplicates(inplace=True)
df_pov.drop_duplicates(inplace=True)

# %%
print(df_mini.shape)
print(df_pov.shape)
# Out:
# (232, 6)
# (232, 6)

# %%
import ast
# Convertir la columna de tipo object a listas de enteros
df_mini['mouse_final'] = df_mini['mouse_final'].apply(ast.literal_eval)
df_pov['mouse_final'] = df_pov['mouse_final'].apply(ast.literal_eval)

# %%
# Modificar el valor de la segunda posición en cada array de la columna 'mouse_final' a 0
df_mini['mouse_final'] = df_mini['mouse_final'].apply(lambda x: [x[0], 0])
df_pov['mouse_final'] = df_pov['mouse_final'].apply(lambda x: [x[0], 0])

# %%
fig, axes = plt.subplots(3, 5, figsize=(15, 5))

for i in range(3): 
    for j in range(5):
        # Obtener la ruta de la imagen
        ruta_imagen = df_mini.iloc[i, j]  # Elimina los corchetes
        
        # Abrir la imagen y convertirla a matriz numpy
        imagen = Image.open("../" + ruta_imagen)
        matriz_np = np.array(imagen)
        
        # Mostrar la imagen en el subplot correspondiente
        axes[i, j].imshow(matriz_np)
        axes[i, j].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 5, figsize=(15, 5))

for i in range(3): 
    for j in range(5):
        # Obtener la ruta de la imagen
        ruta_imagen = df_pov.iloc[i, j]  # Elimina los corchetes
        
        # Abrir la imagen y convertirla a matriz numpy
        imagen = Image.open("../" + ruta_imagen)
        matriz_np = np.array(imagen)
        
        # Mostrar la imagen en el subplot correspondiente
        axes[i, j].imshow(matriz_np)
        axes[i, j].axis('off')

plt.tight_layout()
plt.show()

# %%
primera_fila = df_mini.iloc[0]
imagen = Image.open("../" +str(primera_fila.iloc[1]))
matriz_np = np.array(imagen)  
print("Tamaño imagen -> "+str(imagen.size))
print("Tamaño matriz -> "+ str(matriz_np.shape))
plt.imshow(matriz_np)
plt.axis('on')
plt.show()
# Out:
# Tamaño imagen -> (300, 225)
# Tamaño matriz -> (225, 300, 3)

# %%
primera_fila = df_pov.iloc[0]
imagen = Image.open("../" +str(primera_fila.iloc[1]))
matriz_np = np.array(imagen)  
print("Tamaño imagen -> "+str(imagen.size))
print("Tamaño matriz -> "+ str(matriz_np.shape))
plt.imshow(matriz_np)
plt.axis('on')
plt.show()
# Out:
# Tamaño imagen -> (300, 225)
# Tamaño matriz -> (225, 300, 3)

# %% [markdown]
# # Funcion Del Batch

# %%
from keras.utils import Sequence

class ImageDataGenerator(Sequence):
    def __init__(self, df , sequence_length ,image_height , image_width , batch_size, filtro, **kwargs):
        self.df = df
        self.image_sequence_length = sequence_length
        self.image_height = image_height
        self.image_width = image_width
        self.batch_size = batch_size
        self.filtro_SHARPEN = filtro
        super().__init__(**kwargs)  # Llamada al constructor de la clase base
        
    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))
    
    def cargar_todo(self,fin_df):
        batch_df = self.df.iloc[0:fin_df]     #Obtenemos un lote del df
        
        X_batch = np.zeros((len(batch_df), self.image_sequence_length ,self.image_height, self.image_width, 3))  # Inicializar matriz para las imágenes
        y_batch = np.array(batch_df['mouse_final'].tolist())
        
        for i, (_, row) in enumerate(batch_df.iterrows()):
            frames = []
            for j in range(self.image_sequence_length):
                imagen = Image.open("../" + row.iloc[j])    # Obtener la ruta de la imagen
                imagen = Image.fromarray(np.array(imagen)).filter(ImageFilter.SHARPEN)  #Aplicamos Filtro SHARPEN
                imagen = np.array(imagen) / 255.0           # Normalizar la imagen

                frames.append(imagen)                  #Juntamos frames en lista
            video = np.stack(frames, axis=0)           # Convertir lista de frames en un video np
            X_batch[i] = video
        
        return X_batch, y_batch
    
    def __getitem__(self, index):
        inicio_lote = index * self.batch_size
        final_lote = (index + 1) * self.batch_size
        
        batch_df = self.df.iloc[inicio_lote:final_lote]     #Obtenemos un lote del df
        
        X_batch = np.zeros((len(batch_df), self.image_sequence_length ,self.image_height, self.image_width, 3))  # Inicializar matriz para las imágenes
        y_batch = np.array(batch_df['mouse_final'].tolist())
        
        for i, (_, row) in enumerate(batch_df.iterrows()):
            frames = []
            for j in range(self.image_sequence_length):
                imagen = Image.open("../" + row.iloc[j])    # Obtener la ruta de la imagen
                imagen = Image.fromarray(np.array(imagen))
                
                if self.filtro_SHARPEN == True :
                    imagen = imagen.filter(ImageFilter.SHARPEN)  #Aplicamos Filtro SHARPEN
                    
                imagen = np.array(imagen) / 255.0           # Normalizar la imagen

                frames.append(imagen)                  #Juntamos frames en lista
            video = np.stack(frames, axis=0)           # Convertir lista de frames en un video np
            X_batch[i] = video
        
        return X_batch, y_batch

def comprobar_contenido(X_train , Y_train , num_video):

    fig, axs = plt.subplots(1, 5, figsize=(5 * 2, 1 * 2))

    for i in range(5):
        axs[i].imshow(X_train[num_video][i])
        axs[i].axis('off')

    plt.tight_layout()
    plt.show()
    print("Etiqueta -> "+ str(Y_train[num_video]))
    return Y_train[num_video]
# Out:
# 2024-07-01 14:05:50.488868: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-01 14:05:50.510398: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI AVX512_BF16, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # PREPARACIÒN ENTRENAMIENTO

# %% [markdown]
# ## Train Split

# %%
# Modelo Mini-Mapa
X_train_Mapa, X_test_Mapa = train_test_split(df_mini, test_size=0.2, random_state=42)
X_train_Mapa, X_valid_Mapa = train_test_split(X_train_Mapa, test_size=0.25, random_state=42)

print("Tamaño total: ",len(df_mini))
print("Tamaño del conjunto de entrenamiento:", len(X_train_Mapa))
print("Tamaño del conjunto de prueba:", len(X_test_Mapa))
print("Tamaño del conjunto de validación:", len(X_valid_Mapa))
# Out:
# Tamaño total:  232
# Tamaño del conjunto de entrenamiento: 138
# Tamaño del conjunto de prueba: 47
# Tamaño del conjunto de validación: 47

# %%
# Modelo POV
X_train_Pov, X_test_Pov = train_test_split(df_pov, test_size=0.2, random_state=42)
X_train_Pov, X_valid_Pov = train_test_split(X_train_Pov, test_size=0.25, random_state=42)

print("Tamaño total: ",len(df_pov))
print("Tamaño del conjunto de entrenamiento:", len(X_train_Pov))
print("Tamaño del conjunto de prueba:", len(X_test_Pov))
print("Tamaño del conjunto de validación:", len(X_valid_Pov))
# Out:
# Tamaño total:  232
# Tamaño del conjunto de entrenamiento: 138
# Tamaño del conjunto de prueba: 47
# Tamaño del conjunto de validación: 47

# %%
fig, axes = plt.subplots(6, 5, figsize=(15, 5))

for i in range(6): 
    for j in range(5):
        # Obtener la ruta de la imagen
        ruta_imagen = X_test_Pov.iloc[i, j]  # Elimina los corchetes
        
        # Abrir la imagen y convertirla a matriz numpy
        imagen = Image.open("../" + ruta_imagen)
        matriz_np = np.array(imagen)
        
        # Mostrar la imagen en el subplot correspondiente
        axes[i, j].imshow(matriz_np)
        axes[i, j].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(6, 5, figsize=(15, 5))

for i in range(6): 
    for j in range(5):
        # Obtener la ruta de la imagen
        ruta_imagen = X_test_Mapa.iloc[i, j]  # Elimina los corchetes
        
        # Abrir la imagen y convertirla a matriz numpy
        imagen = Image.open("../" + ruta_imagen)
        matriz_np = np.array(imagen)
        
        # Mostrar la imagen en el subplot correspondiente
        axes[i, j].imshow(matriz_np)
        axes[i, j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Generadores

# %%
# Generador Mapa

altura_img_mini = 225
anchura_img_mini = 300
batch_size = 1 #videos por batch

# Generadores de Batches Mini-Mapa
train_generator_Mapa = ImageDataGenerator(X_train_Mapa, sequence_length=5, image_height=altura_img_mini, image_width=anchura_img_mini, batch_size=batch_size ,filtro =True)
test_generator_Mapa = ImageDataGenerator(X_test_Mapa, sequence_length=5, image_height=altura_img_mini, image_width=anchura_img_mini, batch_size=batch_size ,filtro =True)
valid_generator_Mapa = ImageDataGenerator(X_valid_Mapa, sequence_length=5, image_height=altura_img_mini, image_width=anchura_img_mini, batch_size=batch_size ,filtro =True)

# %%
#Cantidad de batches en los que se divide el df
print(train_generator_Mapa.__len__())

#Comprobamos funcionamiento bach
X_batch, y_batch = train_generator_Mapa.__getitem__(2)

for i in range(0,batch_size):  # 4 es el maximo de conjunto de imagenes del batch creado
    # Seleccionamos ver la posicion numero 0 del batch creado
    comprobar_contenido(X_batch , y_batch,i)
# Out:
# 138
# Etiqueta -> [-231    0]

# %%
# Generador Pov
altura_img_mini = 225
anchura_img_mini = 300
batch_size = 1 #videos por batch

# Generadores de Batches Pov
train_generator_Pov = ImageDataGenerator(X_train_Pov, sequence_length=5, image_height=altura_img_mini, image_width=anchura_img_mini, batch_size=batch_size ,filtro =True)
test_generator_Pov = ImageDataGenerator(X_test_Pov, sequence_length=5, image_height=altura_img_mini, image_width=anchura_img_mini, batch_size=batch_size ,filtro =True)
valid_generator_Pov = ImageDataGenerator(X_valid_Pov, sequence_length=5, image_height=altura_img_mini, image_width=anchura_img_mini, batch_size=batch_size ,filtro =True)

# %%
#Cantidad de batches en los que se divide el df
print(train_generator_Pov.__len__())

#Comprobamos funcionamiento bach
X_batch, y_batch = train_generator_Pov.__getitem__(2)

for i in range(0,batch_size):  # 2 es el maximo de conjunto de imagenes del batch creado
    # Seleccionamos ver la posicion numero 0 del batch creado
    comprobar_contenido(X_batch , y_batch,i)
# Out:
# 138
# Etiqueta -> [-231    0]

# %% [markdown]
# # Modelo - Entreno

# %%
import tensorflow as tf
from tensorflow.keras.models import Model ,Sequential
from tensorflow.keras.layers import Input, TimeDistributed, MaxPooling2D, Flatten, Dense ,ConvLSTM2D, Dropout,Concatenate ,BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import MeanAbsoluteError

# %%
def creacion_modelo_convLSTM(input_shape_mapa , input_shape_pov):

    #Entrada input videos
    input_shape_mapa = tf.keras.Input(shape=input_shape_mapa) 
    input_shape_pov = tf.keras.Input(shape=input_shape_pov) 

    # ----------------------- MAPA ----------------------- 

    #Capa01 Mapa
    conv_mapa_01 = ConvLSTM2D(filters= 30, kernel_size=(4,4), 
                                    activation='relu', 
                                    padding='same',
                                    return_sequences=True)(input_shape_mapa)
    batch_mapa_01 = TimeDistributed(BatchNormalization())(conv_mapa_01)
    conv_mapa_02 = ConvLSTM2D(filters= 30, kernel_size=(4,4), 
                                activation='relu', 
                                padding='same',
                                return_sequences=True)(batch_mapa_01)
    max_pool_mapa = TimeDistributed(MaxPooling2D(pool_size=(2, 2)))(conv_mapa_02)
    dropout_mapa = TimeDistributed(Dropout(0.5))(max_pool_mapa)

    #Capa02 Mapa
    conv_mapa_03 = ConvLSTM2D(filters= 64, kernel_size=(4,4), 
                                    activation='relu', 
                                    padding='same',
                                    return_sequences=True)(dropout_mapa)
    batch_mapa_02 = TimeDistributed(BatchNormalization())(conv_mapa_03)
    conv_mapa_04 = ConvLSTM2D(filters= 64, kernel_size=(4,4), 
                                activation='relu', 
                                padding='same',
                                return_sequences=True)(batch_mapa_02)
    max_pool_mapa_02 = TimeDistributed(MaxPooling2D(pool_size=(2, 2)))(conv_mapa_04)
    dropout_mapa_02 = TimeDistributed(Dropout(0.5))(max_pool_mapa_02)
    
    #Capa03 Mapa
    conv_mapa_04 = ConvLSTM2D(filters= 128, kernel_size=(4,4), 
                                    activation='relu', 
                                    padding='same',
                                    return_sequences=True)(dropout_mapa_02)
    batch_mapa_03 = TimeDistributed(BatchNormalization())(conv_mapa_04)
    conv_mapa_05 = ConvLSTM2D(filters= 128, kernel_size=(4,4), 
                                activation='relu', 
                                padding='same',
                                return_sequences=True)(batch_mapa_03)
    max_pool_mapa_03 = TimeDistributed(MaxPooling2D(pool_size=(2, 2)))(conv_mapa_05)
    dropout_mapa_03 = TimeDistributed(Dropout(0.5))(max_pool_mapa_03)

    # ----------------------- POV ----------------------- 
    #Capa01 Pov
    conv_pov_01 = ConvLSTM2D(filters= 30, kernel_size=(4,4), 
                                    activation='relu', 
                                    padding='same',
                                    return_sequences=True)(input_shape_pov)
    batch_pov_01 = TimeDistributed(BatchNormalization())(conv_pov_01)
    conv_pov_02 = ConvLSTM2D(filters= 30, kernel_size=(4,4), 
                                activation='relu', 
                                padding='same',
                                return_sequences=True)(batch_pov_01)
    max_pool_pov = TimeDistributed(MaxPooling2D(pool_size=(2, 2)))(conv_pov_02)
    dropout_pov = TimeDistributed(Dropout(0.5))(max_pool_pov)

    #Capa02 Pov
    conv_pov_03 = ConvLSTM2D(filters= 64, kernel_size=(4,4), 
                                    activation='relu', 
                                    padding='same',
                                    return_sequences=True)(dropout_pov)
    batch_pov_02 = TimeDistributed(BatchNormalization())(conv_pov_03)
    conv_pov_04 = ConvLSTM2D(filters= 64, kernel_size=(4,4), 
                                activation='relu', 
                                padding='same',
                                return_sequences=True)(batch_pov_02)
    max_pool_pov02 = TimeDistributed(MaxPooling2D(pool_size=(2, 2)))(conv_pov_04)
    dropout_pov_02 = TimeDistributed(Dropout(0.5))(max_pool_pov02)

    # ----------------------- DENSE -----------------------

    # Aplanar las salidas de ConvLSTM2D
    flat1 = Flatten()(dropout_mapa_03)
    flat2 = Flatten()(dropout_pov_02)
    
    # Concatenar las características aplanadas
    merged_features = Concatenate()([flat1, flat2])
    
    # Capa densa
    dense_out = Dense(100, activation='relu')(merged_features)
    drop_dense = Dropout((0.5))(dense_out)
    
    dense_out_02 = Dense(94, activation='relu')(drop_dense)
    drop_dense_02 = Dropout((0.5))(dense_out_02)
    
    #Capa Salida
    output = Dense(2, activation='linear')(drop_dense_02)

    return input_shape_mapa ,input_shape_pov, output

# %%
timesteps = 5
height = 225
width = 300
channels = 3
input_shape_mapa = (timesteps, height, width, channels) # Modelo Mini-Mapa
input_shape_pov = (timesteps, height, width, channels) # Modelo Pov

input_shape_mapa, input_shape_pov,output = creacion_modelo_convLSTM(input_shape_mapa,input_shape_pov)
# Out:
# 2024-07-01 14:06:00.783175: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-01 14:06:00.812127: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-01 14:06:00.812337: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-01 14:06:00.813485: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-01 14:06:00.813648: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-01 14:06:00.813789: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-01 14:06:00.868728: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-01 14:06:00.868939: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-01 14:06:00.869101: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-01 14:06:00.869206: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6842 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
# Definir y compilar el modelo
model = Model(inputs=[input_shape_mapa, input_shape_pov], outputs=output)

# Compilar el modelo
model.compile(optimizer='adam', loss='mean_squared_error',metrics=[MeanAbsoluteError()])
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5, 225, 300, 3)]     0         []
#
#  conv_lstm2d (ConvLSTM2D)    (None, 5, 225, 300, 30)      63480     ['input_1[0][0]']
#
#  time_distributed (TimeDist  (None, 5, 225, 300, 30)      120       ['conv_lstm2d[0][0]']
#  ributed)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, 5, 225, 300, 30)      115320    ['time_distributed[0][0]']
#
#  time_distributed_1 (TimeDi  (None, 5, 112, 150, 30)      0         ['conv_lstm2d_1[0][0]']
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 5, 112, 150, 30)      0         ['time_distributed_1[0][0]']
#  stributed)
#
#  input_2 (InputLayer)        [(None, 5, 225, 300, 3)]     0         []
#
#  conv_lstm2d_2 (ConvLSTM2D)  (None, 5, 112, 150, 64)      385280    ['time_distributed_2[0][0]']
#
#  conv_lstm2d_6 (ConvLSTM2D)  (None, 5, 225, 300, 30)      63480     ['input_2[0][0]']
#
#  time_distributed_3 (TimeDi  (None, 5, 112, 150, 64)      256       ['conv_lstm2d_2[0][0]']
#  stributed)
#
#  time_distributed_9 (TimeDi  (None, 5, 225, 300, 30)      120       ['conv_lstm2d_6[0][0]']
#  stributed)
#
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 5, 112, 150, 64)      524544    ['time_distributed_3[0][0]']
#
#  conv_lstm2d_7 (ConvLSTM2D)  (None, 5, 225, 300, 30)      115320    ['time_distributed_9[0][0]']
#
#  time_distributed_4 (TimeDi  (None, 5, 56, 75, 64)        0         ['conv_lstm2d_3[0][0]']
#  stributed)
#
#  time_distributed_10 (TimeD  (None, 5, 112, 150, 30)      0         ['conv_lstm2d_7[0][0]']
#  istributed)
#
#  time_distributed_5 (TimeDi  (None, 5, 56, 75, 64)        0         ['time_distributed_4[0][0]']
#  stributed)
#
#  time_distributed_11 (TimeD  (None, 5, 112, 150, 30)      0         ['time_distributed_10[0][0]']
#  istributed)
#
#  conv_lstm2d_4 (ConvLSTM2D)  (None, 5, 56, 75, 128)       1573376   ['time_distributed_5[0][0]']
#
#  conv_lstm2d_8 (ConvLSTM2D)  (None, 5, 112, 150, 64)      385280    ['time_distributed_11[0][0]']
#
#  time_distributed_6 (TimeDi  (None, 5, 56, 75, 128)       512       ['conv_lstm2d_4[0][0]']
#  stributed)
#
#  time_distributed_12 (TimeD  (None, 5, 112, 150, 64)      256       ['conv_lstm2d_8[0][0]']
#  istributed)
#
#  conv_lstm2d_5 (ConvLSTM2D)  (None, 5, 56, 75, 128)       2097664   ['time_distributed_6[0][0]']
#
#  conv_lstm2d_9 (ConvLSTM2D)  (None, 5, 112, 150, 64)      524544    ['time_distributed_12[0][0]']
#
#  time_distributed_7 (TimeDi  (None, 5, 28, 37, 128)       0         ['conv_lstm2d_5[0][0]']
#  stributed)
#
#  time_distributed_13 (TimeD  (None, 5, 56, 75, 64)        0         ['conv_lstm2d_9[0][0]']
#  istributed)
#
#  time_distributed_8 (TimeDi  (None, 5, 28, 37, 128)       0         ['time_distributed_7[0][0]']
#  stributed)
#
#  time_distributed_14 (TimeD  (None, 5, 56, 75, 64)        0         ['time_distributed_13[0][0]']
#  istributed)
#
#  flatten (Flatten)           (None, 663040)               0         ['time_distributed_8[0][0]']
#
#  flatten_1 (Flatten)         (None, 1344000)              0         ['time_distributed_14[0][0]']
#
#  concatenate (Concatenate)   (None, 2007040)              0         ['flatten[0][0]',
#                                                                      'flatten_1[0][0]']
#
#  dense (Dense)               (None, 100)                  2007041   ['concatenate[0][0]']
#                                                           00
#
#  dropout_5 (Dropout)         (None, 100)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 94)                   9494      ['dropout_5[0][0]']
#
#  dropout_6 (Dropout)         (None, 94)                   0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 2)                    190       ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 206563336 (787.98 MB)
# Trainable params: 206562704 (787.97 MB)
# Non-trainable params: 632 (2.47 KB)
# __________________________________________________________________________________________________

# %%
class CombinedDataGenerator(Sequence):
    def __init__(self, generator_mapa, generator_pov, batch_size):
        self.generator_mapa = generator_mapa
        self.generator_pov = generator_pov
        self.batch_size = batch_size

    def __len__(self):
        return min(len(self.generator_mapa), len(self.generator_pov))

    def __getitem__(self, index):
        X_mapa, y_mapa = self.generator_mapa[index]
        X_pov, y_pov = self.generator_pov[index]
        
        # Asegurarse de que las etiquetas sean iguales
        assert np.array_equal(y_mapa, y_pov), "Las etiquetas no coinciden"

        return [X_mapa, X_pov], y_mapa  # o y_pov, ya que son iguales


    def __iter__(self):
        # Devolver un iterador que itera sobre los batches
        for i in range(len(self)):
            yield self[i]

    def on_epoch_end(self):
        self.generator_mapa.on_epoch_end()
        self.generator_pov.on_epoch_end()

# %%
# Crear una instancia del generador combinado
combined_generator = CombinedDataGenerator(train_generator_Mapa, train_generator_Pov, 1)
# Crear una instancia del generador combinado
valid_combine_generator = CombinedDataGenerator(valid_generator_Mapa, valid_generator_Pov, 1)

# %%
imagenes , label = combined_generator.__getitem__(0)

# %%
for i in range(0,1):  # 4 es el maximo de conjunto de imagenes del batch creado
    # Seleccionamos ver la posicion numero 0 del batch creado
    comprobar_contenido(imagenes[0] , label,i)
    comprobar_contenido(imagenes[1] , label,i)
# Out:
# Etiqueta -> [-10   0]
# Etiqueta -> [-10   0]

# %%
import time

# Registro del tiempo de inicio
start_time = time.time()

# Entrenamiento Mini-Mapa
history = model.fit(combined_generator, epochs=1000, validation_data=valid_combine_generator, callbacks=[early_stopping])

model.save('modelo_merge.h5')

# Registro del tiempo de finalización
end_time = time.time()
# Out:
# Epoch 1/1000
# 2024-07-01 14:06:28.389879: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2024-07-01 14:06:29.139761: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8c6c004a70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-01 14:06:29.139777: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1070, Compute Capability 6.1
# 2024-07-01 14:06:29.142640: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-01 14:06:29.205253: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 138/138 [==============================] - 173s 1s/step - loss: 7448.6982 - mean_absolute_error: 29.1823 - val_loss: 14614.8086 - val_mean_absolute_error: 32.3572
# Epoch 2/1000
# 138/138 [==============================] - 161s 1s/step - loss: 7245.1143 - mean_absolute_error: 27.1617 - val_loss: 14554.3125 - val_mean_absolute_error: 33.2419
# Epoch 3/1000
# 138/138 [==============================] - 162s 1s/step - loss: 7243.5371 - mean_absolute_error: 28.5900 - val_loss: 14763.5283 - val_mean_absolute_error: 34.1411
# Epoch 4/1000
# 138/138 [==============================] - 163s 1s/step - loss: 7244.5430 - mean_absolute_error: 28.2070 - val_loss: 14657.2949 - val_mean_absolute_error: 32.6146
# Epoch 5/1000
# 138/138 [==============================] - 170s 1s/step - loss: 7272.9404 - mean_absolute_error: 28.2897 - val_loss: 14883.8486 - val_mean_absolute_error: 34.9462
# Epoch 6/1000
# 138/138 [==============================] - 169s 1s/step - loss: 7336.7148 - mean_absolute_error: 31.0786 - val_loss: 14618.4082 - val_mean_absolute_error: 32.4630
# Epoch 7/1000
# 138/138 [==============================] - 169s 1s/step - loss: 7242.9780 - mean_absolute_error: 27.2471 - val_loss: 14612.2607 - val_mean_absolute_error: 32.4875
# Epoch 8/1000
# 138/138 [==============================] - 170s 1s/step - loss: 7226.4248 - mean_absolute_error: 26.4731 - val_loss: 14615.9160 - val_mean_absolute_error: 32.3590
# Epoch 9/1000
# 138/138 [==============================] - 170s 1s/step - loss: 7215.5420 - mean_absolute_error: 26.4139 - val_loss: 14616.0039 - val_mean_absolute_error: 32.3580
# Epoch 10/1000
# 138/138 [==============================] - ETA: 0s - loss: 7215.1440 - mean_absolute_error: 26.3934

# %%
# Calcula la diferencia de tiempo en segundos
training_time_seconds = end_time - start_time

# Convierte el tiempo de entrenamiento a horas
training_time_hours = training_time_seconds / 3600  # 3600 segundos en una hora

# Imprime el tiempo de entrenamiento en horas
print(f"El entrenamiento duró aproximadamente {training_time_hours:.2f} horas.")
# Out:
# El entrenamiento duró aproximadamente 0.49 horas.

# %%
# Crear una instancia del generador combinado
test_generator = CombinedDataGenerator(test_generator_Mapa, test_generator_Pov, 1)

# %%
resultado = model.evaluate(test_generator)
# Out:
# 47/47 [==============================] - 14s 295ms/step - loss: 8746.8096 - mean_absolute_error: 28.2004

# %%
resultado
# Out:
# [8746.8095703125, 28.200353622436523]

# %% [markdown]
# # Pruebas

# %% [markdown]
# ## Densa 84
# ![Captura%20desde%202024-07-01%2000-16-30.png](attachment:Captura%20desde%202024-07-01%2000-16-30.png)

# %% [markdown]
# ## Densa 94
# ![Captura%20desde%202024-07-01%2000-22-32.png](attachment:Captura%20desde%202024-07-01%2000-22-32.png)

# %% [markdown]
# ##  Densa 100
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Añadiendo segunda capa de 64
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Añadiendo segunda capa de 84
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Capa tercera capa de 248
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Capa tercera capa de 124
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Capa tercera capa de 94
#
# ![imagen.png](attachment:imagen.png)
